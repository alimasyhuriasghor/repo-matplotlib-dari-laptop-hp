# %% [markdown]
# # Ngulang Materi Part 18

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
devs = ['Python','JavaScript','C++','Java','C#']
salaries = [6500,5000,4650,4000,3500]

# %%
fig, ax = plt.subplots(ncols=2,nrows=2,constrained_layout=True)

fig.suptitle('Simple 2x2 Layout With Subplots')
ax[0][0].bar(devs,salaries)
ax[0][1].pie(salaries,labels=devs,autopct='%1.1f%%',explode=[0.1,0,0,0,0])
ax[1][0].pie(salaries,labels=devs,autopct='%1.1f%%',explode=[0,0.1,0,0,0])
ax[1][1].barh(devs,salaries)

plt.show()

# %%
fig = plt.figure(constrained_layout=True)
gs = fig.add_gridspec(ncols=2,nrows=2)

ax1 = fig.add_subplot(gs[0,:])
# ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

ax1.bar(devs,salaries)
ax2.pie(salaries,labels=devs,autopct='%1.1f%%',explode=[0.1,0,0,0,0])
ax3.pie(salaries,labels=devs,autopct='%1.1f%%',explode=[0.1,0,0,0,0])
ax4.barh(devs,salaries)

plt.show()

# %%
devs = ['Python','JavaScript','C++','Java']
salaries = [6500,5000,4650,4000]

# %%
fig = plt.figure(constrained_layout=True)
gs = gridspec.GridSpec(ncols=2,nrows=2,figure=fig)

fig.suptitle('Simple 2x2 Layout With Gridspec')
ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[1,0])
ax4 = fig.add_subplot(gs[1,1])

ax1.bar(devs,salaries)
ax2.pie(salaries,labels=devs,autopct='%1.1f%%',explode=[0.1,0,0,0])
ax3.pie(salaries,labels=devs,autopct='%1.1f%%',explode=[0,0.1,0,0])
ax4.barh(devs,salaries)

plt.show()
